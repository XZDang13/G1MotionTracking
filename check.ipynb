# %%
import numpy as np

# %%
data_1 = np.load("env/assests/jab.npz")

# %%
data_1["joint_vel"].shape
# Out:
# (84, 23)

# %%
data_2 = np.load("jab.npz")

# %%
data_2["joint_vel"].shape
# Out:
# (98, 23)

# %%
data_1["fps"]
# Out:
# array(30)

# %%
data_2["fps"]
# Out:
# array(30)

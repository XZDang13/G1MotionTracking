# %%
from Ref2Act.motion_lib import MotionLib

# %%
motion_lib = MotionLib("env/assests/pick.npz")
# Out:
# motion data loaded: 6.233333333333333 s

# %%
motion_lib.joint_vel[0]
# Out:
# tensor([ 0.8264,  0.5231,  0.6919, -0.7613,  0.5323,  0.5645,  1.2798, -3.7291,
#          0.4841,  0.7208, -0.2351, -1.7407, -0.1236, -1.3113,  0.8706,  0.2379,
#          0.2351,  0.2751, -1.1553, -3.2377,  0.2281,  0.5477,  0.1272])

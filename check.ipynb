# %%
import torch

# %%
weight = torch.load("weight.pth")

# %%
weight
# Out:
# {'actor_norm': OrderedDict([('mean',
#                tensor([ 3.0088e-02, -1.6018e-01, -9.8625e-02,  3.0424e-01, -5.1004e-01,
#                        -9.3101e-01, -4.2167e-01,  3.1009e-01, -4.0701e-01,  3.9002e-01,
#                        -7.3894e-01,  2.0315e-01,  2.6011e-01, -3.3610e-01, -4.1713e-01,
#                        -2.9428e-01, -1.1595e-01, -3.5039e-01, -4.4276e-01, -7.3564e-02,
#                         1.8942e-01, -2.9129e-01,  2.8497e-01,  3.0217e-02,  8.4103e-02,
#                         1.8882e-03, -6.8997e-03,  1.2515e-03, -7.1035e-03,  2.9372e-03,
#                        -3.4073e-03, -7.4674e-02,  7.0235e-02, -8.6693e-02, -6.7118e-02,
#                        -2.6229e-02, -1.6388e-04, -5.9727e-02,  2.6761e-02, -4.0595e-02,
#                        -1.5409e-02,  1.7086e-02, -2.3812e-02,  2.0928e-02, -6.6693e-02,
#                        -2.5231e-02,  1.8399e-02, -6.1443e-02, -9.9748e-01,  3.6607e-02,
# ...
